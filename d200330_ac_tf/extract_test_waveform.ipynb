# %%
from CHECLabPy.core.io import TIOReader
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
reader = TIOReader("/Users/Jason/Downloads/tempdata/mpik_tf/r1_test/Amplitude_800_r1.tio")
wf = reader[1][0]
plt.plot(wf)

# %%
np.savetxt("test_wf.txt", wf, fmt='%.3f')
